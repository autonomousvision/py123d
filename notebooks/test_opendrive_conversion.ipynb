# %%
import matplotlib.pyplot as plt
from shapely.geometry import LineString, Polygon, Point
import numpy as np

from typing import List

from asim.dataset.dataset_specific.carla.opendrive.elements.lane import Lane, LaneSection
from asim.dataset.dataset_specific.carla.opendrive.elements.reference import Border

# %%
from pathlib import Path
from asim.dataset.dataset_specific.carla.opendrive.elements.opendrive import OpenDrive

town_name = "Town03"

if town_name not in ["Town11", "Town12", "Town13", "Town15"]:
    carla_maps_root = Path("/home/daniel/carla_workspace/carla_garage/carla/CarlaUE4/Content/Carla/Maps/OpenDrive")
    carla_map_path = carla_maps_root / f"{town_name}.xodr"

else:
    carla_map_path = f"/home/daniel/carla_workspace/carla_garage/carla/CarlaUE4/Content/Carla/Maps/{town_name}/OpenDrive/{town_name}.xodr"

opendrive = OpenDrive.parse_from_file(carla_map_path)

# %%
town_name.lower()
# Out:
# 'town03'

# %%
from asim.dataset.dataset_specific.carla.opendrive.opendrive_converter import OpenDriveConverter


converter =  OpenDriveConverter(opendrive)

converter.run(f"carla_{town_name.lower()}")


# TODO:

# Add lane:
#
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       1 from asim.dataset.dataset_specific.carla.opendrive.opendrive_converter import OpenDriveConverter
#       4 converter =  OpenDriveConverter(opendrive)
# ----> 6 converter.run(f"carla_{town_name.lower()}")
#       9 # TODO:
#      10
#      11 # Add lane:
#      12 #
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/opendrive_converter.py:47, in OpenDriveConverter.run(self, map_name)
#      45 self._update_connection_from_junctions()
#      46 self._flip_and_set_connections()
# ---> 47 self._post_process_connections()
#      48 self._collect_lane_groups()
#      50 # Collect data frames and store
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/opendrive_converter.py:214, in OpenDriveConverter._post_process_connections(self)
#     211 for lane_id in self.lane_helper_dict.keys():
#     212     self.lane_helper_dict[lane_id]
# --> 214     centerline = self.lane_helper_dict[lane_id].center_polyline_se2
#     216     valid_successor_lane_ids: List[str] = []
#     217     for successor_lane_id in self.lane_helper_dict[lane_id].successor_lane_ids:
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/conversion/group_collections.py:109, in OpenDriveLaneHelper.center_polyline_se2(self)
#     107 @property
#     108 def center_polyline_se2(self) -> npt.NDArray[np.float64]:
# --> 109     return np.concatenate([self.inner_polyline_se2[None, ...], self.outer_polyline_se2[None, ...]], axis=0).mean(
#     110         axis=0
#     111     )
#
# File ~/anaconda3/envs/asim/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/conversion/group_collections.py:88, in OpenDriveLaneHelper.outer_polyline_se2(self)
#      85 @cached_property
#      86 def outer_polyline_se2(self) -> npt.NDArray[np.float64]:
#      87     outer_polyline = np.array(
# ---> 88         [
#      89             self.outer_border.interpolate_se2(s - self.s_range[0], is_last_pos=is_last)
#      90             for s, is_last in zip(self._s_positions, self._is_last_mask)
#      91         ],
#      92         dtype=np.float64,
#      93     )
#      94     return np.flip(outer_polyline, axis=0) if self.id > 0 else outer_polyline
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/conversion/group_collections.py:89, in <listcomp>(.0)
#      85 @cached_property
#      86 def outer_polyline_se2(self) -> npt.NDArray[np.float64]:
#      87     outer_polyline = np.array(
#      88         [
# ---> 89             self.outer_border.interpolate_se2(s - self.s_range[0], is_last_pos=is_last)
#      90             for s, is_last in zip(self._s_positions, self._is_last_mask)
#      91         ],
#      92         dtype=np.float64,
#      93     )
#      94     return np.flip(outer_polyline, axis=0) if self.id > 0 else outer_polyline
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/elements/reference.py:157, in Border.interpolate_se2(self, s, t, is_last_pos)
#     154     s = 0
#     156 try:
# --> 157     se2 = self.reference.interpolate_se2(self.s_offset + s, is_last_pos=is_last_pos)
#     158 except TypeError:
#     159     se2 = self.reference.interpolate_se2(np.round(self.s_offset + s, 3), is_last_pos=is_last_pos)
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/elements/reference.py:157, in Border.interpolate_se2(self, s, t, is_last_pos)
#     154     s = 0
#     156 try:
# --> 157     se2 = self.reference.interpolate_se2(self.s_offset + s, is_last_pos=is_last_pos)
#     158 except TypeError:
#     159     se2 = self.reference.interpolate_se2(np.round(self.s_offset + s, 3), is_last_pos=is_last_pos)
#
#     [... skipping similar frames: Border.interpolate_se2 at line 157 (1 times)]
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/elements/reference.py:157, in Border.interpolate_se2(self, s, t, is_last_pos)
#     154     s = 0
#     156 try:
# --> 157     se2 = self.reference.interpolate_se2(self.s_offset + s, is_last_pos=is_last_pos)
#     158 except TypeError:
#     159     se2 = self.reference.interpolate_se2(np.round(self.s_offset + s, 3), is_last_pos=is_last_pos)
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/carla/opendrive/elements/reference.py:153, in Border.interpolate_se2(self, s, t, is_last_pos)
#     149 def interpolate_se2(self, s: float, t: float = 0.0, is_last_pos: bool = False) -> npt.NDArray[np.float64]:
#     150     # Last reference has to be a reference geometry (PlanView)
#     151     # Offset of all inner lanes (Border)
#     152     # calculate position of reference border
# --> 153     if np.isclose(s, 0):
#     154         s = 0
#     156     try:
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/numpy/_core/numeric.py:2418, in isclose(a, b, rtol, atol, equal_nan)
#    2414     y = float(y)
#    2416 with errstate(invalid='ignore'), _no_nep50_warning():
#    2417     result = (less_equal(abs(x-y), atol + rtol * abs(y))
# -> 2418               & isfinite(y)
#    2419               | (x == y))
#    2420     if equal_nan:
#    2421         result |= isnan(x) & isnan(y)
#
# KeyboardInterrupt:

# %%
import geopandas as gpd

import pyogrio

map_file_path = Path("/home/daniel/asim_workspace/asim/notebooks/carla_town01.gpkg")
print(map_file_path.with_suffix("").name)

layers = list(gpd.list_layers(map_file_path).name)
print(layers)

layer = layers[0]

print(layer)

gpd.read_file(map_file_path, layer=layer).keys()
# Out:
# carla_town01
# ['lane', 'walkways', 'carpark', 'generic_drivable', 'lane_group']
# lane
# Index(['id', 'predecessor_ids', 'successor_ids', 'left_boundary',
#        'right_boundary', 'baseline_path', 'geometry'],
#       dtype='object')

# %%
from asim.dataset.maps.map_datatypes import MapSurfaceType


str(MapSurfaceType.GENERIC_DRIVABLE).split(".")[-1].lower()


MapSurfaceType.GENERIC_DRIVABLE.name

MapSurfaceType.deserialize(MapSurfaceType.GENERIC_DRIVABLE.name)


MapSurfaceType.GENERIC_DRIVABLE.name.lower().islower()


AVAILABLE_MAP_LAYERS = list(MapSurfaceType)
AVAILABLE_MAP_LAYERS

pyogrio.read_dataframe().
# Out:
#   Cell In[6], line 18
#     pyogrio.read_dataframe().
#                              ^
# SyntaxError: invalid syntax

# %%
# types = []
# for lane_helper in converter.lane_helper_dict.values():
#     types += [lane_helper.type]


# types = print(town_name, set(types))
# types

# Town03 {'driving', 'median', 'none', 'bidirectional', 'parking', 'sidewalk', 'border', 'shoulder'}


# {'driving', 'shoulder', 'sidewalk'}
# {"bidirectional", "border", "driving", "median", "none", "parking", "shoulder", "sidewalk"}
# {'driving', 'none', 'shoulder', 'sidewalk'}2
# {'driving', 'parking', 'shoulder', 'sidewalk'}
# {'driving', 'median', 'none', 'shoulder'}

gdf = converter._extract_lane_dataframe()
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax)

fig.savefig("town_3.pdf")

# %%
gdf = converter._extract_lane_group_dataframe()
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax)

fig.savefig("town_3.pdf")

# %%
gdf = converter._extract_walkways_dataframe()

gdf.plot()

# %%
gdf = converter._extract_carpark_dataframe()

gdf.plot()

# %%
len(converter.lane_helper_dict)

# %%
from asim.common.visualization.color.lib.opendrive import OPENDRIVE_LANE_CUSTOM


def plot_opendrive_converter(converter: OpenDriveConverter) -> None:

    fig, ax = plt.subplots(figsize=(50, 50))

    for lane_helper in converter.lane_helper_dict.values():
        polygon = lane_helper.shapely_polygon
        exterior_x, exterior_y = polygon.exterior.xy
        ax.fill(
            exterior_x,
            exterior_y,
            color=OPENDRIVE_LANE_CUSTOM[lane_helper.type].hex,
            linewidth=0.0,
            alpha=1.0,
        )
        # if lane_helper.type == "driving":
        #     centerline = lane_helper.center_polyline

        #     ax.plot(
        #         centerline[..., 0],
        #         centerline[..., 1],
        #         color="black",
        #         linewidth=0.1,
        #         alpha=0.5,
        #     )



    ax.set_aspect("equal")
    return fig, ax

fig, ax = plot_opendrive_converter(converter)
fig.savefig("test.pdf")

# %%
from asim.common.visualization.color.lib.opendrive import OPENDRIVE_LANE_CUSTOM


def plot_opendrive_converter_lane_groups(converter: OpenDriveConverter) -> None:

    fig, ax = plt.subplots(figsize=(10, 10))

    for lane_group_helper in converter.lane_group_helper_dict.values():
        polygon = lane_group_helper.shapely_polygon
        exterior_x, exterior_y = polygon.exterior.xy
        ax.fill(
            exterior_x,
            exterior_y,
            linewidth=0.0,
            alpha=1.0,
        )
        # color=OPENDRIVE_LANE_CUSTOM[lane_helper.type].hex,
        # if lane_helper.type == "driving":
        #     centerline = lane_helper.center_polyline

        #     ax.plot(
        #         centerline[..., 0],
        #         centerline[..., 1],
        #         color="black",
        #         linewidth=0.1,
        #         alpha=0.5,
        #     )



    ax.set_aspect("equal")
    return fig, ax

fig, ax = plot_opendrive_converter_lane_groups(converter)
fig.savefig("test.pdf")
