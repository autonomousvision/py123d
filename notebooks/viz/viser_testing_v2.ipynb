# %%
import sys
sys.path.append("/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123/tool/nuscenes-devkit/python-sdk")
sys.path.append("/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123")
import os
os.environ["D123_DEVKIT_ROOT"] = "/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123"
os.environ["D123_DATA_ROOT"] = "/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data"
os.environ["D123_MAPS_ROOT"] = "/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data/maps"
os.environ["D123_EXP_ROOT"] = "/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/exp"
os.environ["NUPLAN_DATA_ROOT"] = "/inspire/hdd/project/roboticsystem2/public/nuplan/dataset"
os.environ["NUPLAN_MAPS_ROOT"] = "/inspire/hdd/project/roboticsystem2/public/nuplan/dataset/maps"
os.environ["NUSCENES_DATA_ROOT"] = "/inspire/hdd/project/roboticsystem2/public/nuscenes"
os.environ["NUSCENES_MAPS_ROOT"] = "/inspire/hdd/project/roboticsystem2/public/nuscenes"
os.environ["CARLA_DATA_ROOT"] = "/nas/shared/opendrivelab/nuplan/dataset"

from d123.common.visualization.viser.server import ViserVisualizationServer

from pathlib import Path
from d123.dataset.scene.arrow_scene import ArrowScene

# %%
log_file = Path(f"/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data/train/28e4134bcd664522907277f1ceec2893.arrow")

scene = ArrowScene(log_file)

visualization_server = ViserVisualizationServer(scenes=[scene])
# Out:
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8080   │
# │   Websocket │ ws://localhost:8080     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# /inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123/d123/dataset/maps/gpkg/gpkg_map.py:76: UserWarning: GPKGMap: road_edge not available in /inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data/maps/nuscenes_boston-seaport.gpkg
#   warnings.warn(f"GPKGMap: {map_layer_name} not available in {str(self._file_path)}")
# dict_keys([<MapLayer.LANE_GROUP: 1>, <MapLayer.LANE: 0>, <MapLayer.WALKWAY: 4>, <MapLayer.CROSSWALK: 3>, <MapLayer.CARPARK: 5>, <MapLayer.GENERIC_DRIVABLE: 6>])
# (viser) Connection opened (0, 1 total), 75 persistent messages
# ---------------------------------------------------------------------------
# ...

# %%
#Daniel

# log_name = "Town12_Rep0_longest6_route17_06_03_21_40_12" # Town3
log_name = "2021.09.29.17.35.58_veh-44_01671_01819" # Town4
log_file = Path(f"/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data/train/03ee880dd4e348f4b3407f0d073c7c70.arrow")

# log_name = "_Rep0_longest1_route0_07_04_10_18_47"
# log_file = Path(f"/home/daniel/d123_workspace/data/carla/{log_name}.arrow")
scene = ArrowScene(log_file)

visualization_server = ViserVisualizationServer(scenes=[scene])
# Out:
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8083   │
# │   Websocket │ ws://localhost:8083     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# dict_keys([<MapLayer.LANE_GROUP: 1>, <MapLayer.LANE: 0>, <MapLayer.WALKWAY: 4>, <MapLayer.CROSSWALK: 3>, <MapLayer.CARPARK: 5>, <MapLayer.GENERIC_DRIVABLE: 6>])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_294768/1481514126.py in ?()
# ---> 11 #Daniel
#      12
#      13 # log_name = "Town12_Rep0_longest6_route17_06_03_21_40_12" # Town3
#      14 log_name = "2021.09.29.17.35.58_veh-44_01671_01819" # Town4
#
# /inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123/d123/common/visualization/viser/server.py in ?(self, scenes, scene_index, host, port, label)
# ...

# %%
# -rw-rw-r-- 1 jingchanghui jingchanghui 163162 Aug 14 15:39 c075fbdd97124beaba95bc5c25149f30.arrow
log_name = "2021.09.29.17.35.58_veh-44_01671_01819" # Town4
log_file = Path(f"/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data/train/b0be2e24e2234947867c7f555f6f59d2.arrow")

# log_name = "_Rep0_longest1_route0_07_04_10_18_47"
# log_file = Path(f"/home/daniel/d123_workspace/data/carla/{log_name}.arrow")
scene = ArrowScene(log_file)

visualization_server = ViserVisualizationServer(scenes=[scene])
# Out:
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8083   │
# │   Websocket │ ws://localhost:8083     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# dict_keys([<MapLayer.LANE_GROUP: 1>, <MapLayer.LANE: 0>, <MapLayer.WALKWAY: 4>, <MapLayer.CROSSWALK: 3>, <MapLayer.CARPARK: 5>, <MapLayer.GENERIC_DRIVABLE: 6>])
# (viser) Connection opened (0, 1 total), 51 persistent messages
# (viser) Connection closed (0, 0 total)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123/notebooks/viz/viser_testing_v2.ipynb Cell 4 line 9
# ...

# %%
ego_vehicle_state = scene.get_ego_state_at_iteration(0)

# %%
ego_vehicle_state.vehicle_parameters.height/2 - ego_vehicle_state.vehicle_parameters.height/3

# %%
# log_name = "Town12_Rep0_longest6_route17_06_03_21_40_12" # Town3
log_name = "2021.09.29.17.35.58_veh-44_01671_01819" # Town4
log_file = Path(f"/inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/data/train/bc219c0fa63b43b4b9dddab47fce1fef.arrow")

# log_name = "_Rep0_longest1_route0_07_04_10_18_47"
# log_file = Path(f"/home/daniel/d123_workspace/data/carla/{log_name}.arrow")
scene = ArrowScene(log_file)

visualization_server = ViserVisualizationServer(scenes=[scene])
# Out:
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8083   │
# │   Websocket │ ws://localhost:8083     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# dict_keys([<MapLayer.LANE_GROUP: 1>, <MapLayer.LANE: 0>, <MapLayer.WALKWAY: 4>, <MapLayer.CROSSWALK: 3>, <MapLayer.CARPARK: 5>, <MapLayer.GENERIC_DRIVABLE: 6>])
# (viser) Connection opened (0, 1 total), 73 persistent messages
# (viser) Connection closed (0, 0 total)
# (viser) Connection closed (0, 0 total)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /inspire/hdd/project/roboticsystem2/jingzhanghui-253108140204/d123_workspace/d123/notebooks/viz/viser_testing_v2.ipynb Cell 8 line 9
# ...
