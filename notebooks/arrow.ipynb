# %%
import os, psutil

def print_memory_usage():
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    print(f"Memory usage: {memory_info.rss / 1024 ** 2:.2f} MB")

print_memory_usage()
# Out:
# Memory usage: 331.47 MB

# %%
from geoarrow.pyarrow import io
import tempfile
import geopandas
import os


import shapely.geometry as geom
from asim.dataset.maps.gpkg.gpkg_map import GPKGMap
from asim.dataset.maps.map_datatypes import MapSurfaceType


temp_gpkg = "/home/daniel/asim_workspace/data/maps/carla_town01.gpkg"

print_memory_usage()
map_api = GPKGMap(temp_gpkg)
print_memory_usage()
map_api.initialize()
print_memory_usage()


table = map_api._gpd_dataframes[MapSurfaceType.LANE]

# import pyarrow as pa
# pa.table(table).schema

print_memory_usage()
inter = table.sindex.query(geom.box(-10, -10, 10, 10), predicate='intersects')
# Out:
# Memory usage: 331.47 MB
# Memory usage: 331.47 MB
# Memory usage: 331.47 MB
# Memory usage: 331.47 MB
# Memory usage: 331.47 MB
# array([31, 30, 26, 27])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 pa_table = pa.table(table)
#       2 pa_table.schema
#
# NameError: name 'pa' is not defined

# %%
import geoarrow.pyarrow as ga


from shapely import node
from shapely.strtree import STRtree
ga_array =  ga.as_geoarrow([str(i) for i  in pa_table["left_boundary"]])
# ga_array.wkb()
print_memory_usage()

STRtree([el.to_shapely() for el in ga_array], node_capacity=10)
print_memory_usage()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 6
#       4 from shapely import node
#       5 from shapely.strtree import STRtree
# ----> 6 ga_array =  ga.as_geoarrow([str(i) for i  in pa_table["left_boundary"]])
#       7 # ga_array.wkb()
#       8 print_memory_usage()
#
# NameError: name 'pa_table' is not defined

# %%
import pyarrow.ipc as ipc
import pyarrow as pa

# Save to Arrow IPC file
with pa.OSFile("data.arrow", "wb") as sink:
    with ipc.new_file(sink, pa_table.schema) as writer:
        writer.write_table(pa_table)

# Load with memory mapping
with pa.memory_map("data.arrow", "r") as source:
    pa_table = ipc.open_file(source).read_all()

# %%
import geoarrow.pandas as gap


gap.GeoArrowExtensionDtype
# Out:
# geoarrow.pandas.lib.GeoArrowExtensionDtype

# %%
print_memory_usage()
# Load with memory mapping
with pa.memory_map('data.arrow', 'r') as source:
    table_mmap = ipc.open_file(source).read_all()
print_memory_usage()

STRtree([el.to_shapely() for el in table_mmap["geometry"]], node_capacity=10)
print_memory_usage()
# Out:
# Memory usage: 508.50 MB
# Memory usage: 498.82 MB
# Memory usage: 508.82 MB

# %%
from shapely.geometry import mapping
table_mmap["geom"].apply(lambda geom: mapping(geom.to_shapely()) if geom else None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 from shapely.geometry import mapping
# ----> 2 table_mmap["geom"].apply(lambda geom: mapping(geom.to_shapely()) if geom else None)
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/pyarrow/table.pxi:1707, in pyarrow.lib._Tabular.__getitem__()
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/pyarrow/table.pxi:1793, in pyarrow.lib._Tabular.column()
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/pyarrow/table.pxi:1729, in pyarrow.lib._Tabular._ensure_integer_index()
#
# KeyError: 'Field "geom" does not exist in schema'
