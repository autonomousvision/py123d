# %%
from functools import partial
from pathlib import Path
from typing import Iterator, List, Optional, Set, Union


import pyarrow as pa
from nuplan.planning.utils.multithreading.worker_pool import WorkerPool

from asim.dataset.arrow.helper import open_arrow_arrow_table
from asim.dataset.dataset_specific.nuplan.nuplan_data_processor import worker_map
from asim.dataset.logs.log_metadata import LogMetadata
from asim.dataset.scene.abstract_scene import AbstractScene
from asim.dataset.scene.arrow_scene import ArrowScene, SceneExtractionInfo
from asim.dataset.scene.scene_filter import SceneFilter

# %%
import numpy as np

DURATION_SECONDS = 10.0  
HISTORY_SECONDS = 3.0
ITERATION_DURATION_SECONDS = 0.1



log_path = "/home/daniel/asim_workspace/data/nuplan_mini_val/2021.06.07.12.54.00_veh-35_01843_02314.arrow"

recording_table = open_arrow_arrow_table(log_path)
log_metadata = LogMetadata.from_arrow_table(recording_table)


# scene_tokens = [str(token) for token in np.random.choice(recording_table.column("token").to_pylist(), size=10)]
scene_tokens = None
timestamp_threshold_s: float = 10.0
# timestamp_threshold_s = None
filter = SceneFilter(scene_tokens=scene_tokens, timestamp_threshold_s=timestamp_threshold_s)

# %%
scene_tokens

# %%
def _get_scene_extraction_info(log_path: str, filter: SceneFilter) -> List[SceneExtractionInfo]:
    scene_extraction_infos: List[SceneExtractionInfo] = []

    recording_table = open_arrow_arrow_table(log_path)
    log_metadata = LogMetadata.from_arrow_table(recording_table)

    # 1. Filter map name
    if filter.map_names is not None and log_metadata.map_name not in filter.map_names:
        return scene_extraction_infos

    start_idx = int(filter.history_s / log_metadata.timestep_seconds)
    end_idx = len(recording_table) - int(filter.duration_s / log_metadata.timestep_seconds)

    scene_token_set = set(filter.scene_tokens) if filter.scene_tokens else None

    for idx in range(start_idx, end_idx):
        scene_extraction_info: Optional[SceneExtractionInfo] = None

        if scene_token_set is None:
            scene_extraction_info = SceneExtractionInfo(
                initial_token=str(recording_table["token"][idx]),
                initial_idx=idx,
                duration_s=filter.duration_s,
                history_s=filter.history_s,
                iteration_duration_s=ITERATION_DURATION_SECONDS,
            )
        elif str(recording_table["token"][idx]) in scene_token_set:
            scene_extraction_info = SceneExtractionInfo(
                initial_token=str(recording_table["token"][idx]),
                initial_idx=idx,
                duration_s=filter.duration_s,
                history_s=filter.history_s,
                iteration_duration_s=ITERATION_DURATION_SECONDS,
            )

        if scene_extraction_info is not None:
            # TODO: add more options
            if filter.timestamp_threshold_s is not None and len(scene_extraction_infos) > 0:
                iteration_delta = idx - scene_extraction_infos[-1].initial_idx
                if (iteration_delta * log_metadata.timestep_seconds) < filter.timestamp_threshold_s:
                    continue

            scene_extraction_infos.append(scene_extraction_info)

    del recording_table, log_metadata
    return scene_extraction_infos


scenes = _get_scene_extraction_info(log_path, filter)
len(scenes)

# 4580
# Out:
# 46

# %%
_get_scene_extraction_info(log_path, filter)
# Out:
# [SceneExtractionInfo(initial_token='ad33380b23955e31', initial_idx=30, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='7f118ffa30605a10', initial_idx=130, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='be885a96fabc5bb2', initial_idx=230, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='95e040e5801b5328', initial_idx=330, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='291b3d7fea6251cc', initial_idx=430, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='bca4781479b552a5', initial_idx=530, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='e6f9504ca6ce524e', initial_idx=630, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='39be9b8cebeb5e34', initial_idx=730, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='9da348b6c94f5180', initial_idx=830, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='03b63f8984fb537a', initial_idx=930, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='501c3d6fd16d5b44', initial_idx=1030, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='c7c0c9b43c3b5bb9', initial_idx=1130, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='90c125037d0b50e2', initial_idx=1230, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='23f9c508c9925906', initial_idx=1330, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='2de3bd19420d5e23', initial_idx=1430, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='cbe51c03c0385ca1', initial_idx=1530, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='cdbae4bc2f3f5f6d', initial_idx=1630, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='25a95be719bb56a7', initial_idx=1730, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='3ebe40cde9985901', initial_idx=1830, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='a4cbbaf99017511a', initial_idx=1930, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='d8e8bf7d91805c2b', initial_idx=2030, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='97fd1833966d5965', initial_idx=2130, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='a17085ecb2615f0c', initial_idx=2230, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='3b502f9645045f62', initial_idx=2330, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='10e954a5f2bb5130', initial_idx=2430, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='48734b01583a524f', initial_idx=2530, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='71dbd46dcc6d503d', initial_idx=2630, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='4418cf025443597c', initial_idx=2730, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='49a8bf476b375363', initial_idx=2830, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='34325a639df15875', initial_idx=2930, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='1fc6113b924e5a9f', initial_idx=3030, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='77d4fbc305785312', initial_idx=3130, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='7072ee22a9695333', initial_idx=3230, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='9048665656515f7c', initial_idx=3330, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='a0b601837cc25f9a', initial_idx=3430, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='20658048bfe85c62', initial_idx=3530, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='b67dd24c4c5a592e', initial_idx=3630, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='177db449cfae57bf', initial_idx=3730, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='329c091fe0a152ec', initial_idx=3830, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='1e8b34cd2a595c00', initial_idx=3930, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='7554fd5ca35f5f12', initial_idx=4030, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='d0a1252579ca55a4', initial_idx=4130, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='f3e752be52b95963', initial_idx=4230, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='43b5549358d35bfa', initial_idx=4330, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='3c10fc99b73d5c21', initial_idx=4430, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1),
#  SceneExtractionInfo(initial_token='acce0b71184053f2', initial_idx=4530, duration_s=10.0, history_s=3.0, iteration_duration_s=0.1)]
