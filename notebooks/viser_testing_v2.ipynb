# %%
from asim.common.visualization.viser.server import ViserVisualizationServer

from pathlib import Path
from asim.dataset.scene.arrow_scene import ArrowScene

# %%
# log_name = "Town12_Rep0_longest6_route17_06_03_21_40_12" # Town3
log_name = "2021.09.29.17.35.58_veh-44_01671_01819" # Town4
log_file = Path(f"/home/daniel/asim_workspace/data/nuplan_private_test/{log_name}.arrow")

# log_name = "_Rep0_longest1_route0_07_04_10_18_47"
# log_file = Path(f"/home/daniel/asim_workspace/data/carla/{log_name}.arrow")
scene = ArrowScene(log_file)

visualization_server = ViserVisualizationServer()

visualization_server.set_scene(scene)

# %%
ego_vehicle_state = scene.get_ego_vehicle_state_at_iteration(0)

# %%
ego_vehicle_state.vehicle_parameters.height/2 - ego_vehicle_state.vehicle_parameters.height/3

# %%
from pyquaternion import Quaternion
import numpy as np
# Example Euler angles (in radians) and rotation sequence
# roll = 0.5  # Rotation about the X-axis (radians)
# pitch = 1.0 # Rotation about the Y-axis (radians)
# yaw = 1.5  # Rotation about the Z-axis (radians)
roll = 1.0  # Rotation about the X-axis (radians)
pitch = 2.0 # Rotation about the Y-axis (radians)
yaw = 1.0  # Rotation about the Z-axis (radians)
rotation_sequence = 'xyz'  # Or 'yxz', 'zxy', etc.

# Create a quaternion from Euler angles
quaternion = Quaternion(axis=[roll, pitch, yaw], sequence=rotation_sequence)


quaternion.yaw_pitch_roll

# %%
from asim.common.datatypes.camera.camera_parameters import get_nuplan_camera_parameters
import numpy as np

fy = get_nuplan_camera_parameters().intrinsics[1, 1]

fov_v = 2 * np.arctan(1080 / (2 * fy))
fov_v

# %%
get_nuplan_camera_parameters().intrinsics, fy
