# %%
from asim.common.visualization.viser.server import ViserVisualizationServer

from pathlib import Path
from asim.dataset.scene.arrow_scene import ArrowScene

# %%
# log_name = "Town12_Rep0_longest6_route17_06_03_21_40_12" # Town3
log_name = "Town12_Rep0_longest6_route18_06_03_21_42_03" # Town4
log_file = Path(f"/home/daniel/asim_workspace/data/carla/{log_name}.arrow")
scene = ArrowScene(log_file)

visualization_server = ViserVisualizationServer()

visualization_server.set_scene(scene)
# Out:
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8080   │
# │   Websocket │ ws://localhost:8080     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# (viser) Connection opened (0, 1 total), 15 persistent messages
# (viser) Connection closed (0, 0 total)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       4 scene = ArrowScene(log_file)
#       6 visualization_server = ViserVisualizationServer()
# ----> 8 visualization_server.set_scene(scene)
#
# File ~/asim_workspace/asim/asim/common/visualization/viser/server.py:103, in ViserVisualizationServer.set_scene(self, scene)
#     100 while True:
#     101     # Update the timestep if we're playing.
#     102     if gui_playing.value:
# --> 103         gui_timestep.value = (gui_timestep.value + 1) % num_frames
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/viser/_gui_handles.py:126, in _OverridableGuiPropApi.__setattr__(self, name, value)
#     124 prop = getattr(self.__class__, name, None)
#     125 if isinstance(prop, property) and prop.fset is not None:
# --> 126     prop.fset(self, value)
#     127     return
#     129 # Otherwise, look for the field in the general props struct.
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/viser/_gui_handles.py:222, in _GuiInputHandle.value(self, value)
#     220 # Send to client, except for buttons.
#     221 if not self._impl.is_button:
# --> 222     self._impl.gui_api._websock_interface.queue_message(
#     223         GuiUpdateMessage(self._impl.uuid, {"value": value})
#     224     )
#     226 # Set internal state. We automatically convert numpy arrays to the expected
#     227 # internal type. (eg 1D arrays to tuples)
#     228 self._impl.value = type(self._impl.value)(value)  # type: ignore
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/viser/infra/_infra.py:163, in WebsockMessageHandler.queue_message(self, message)
#     160 if self._record_handle is not None:
#     161     self._record_handle._insert_message(message)
# --> 163 self.get_message_buffer().push(message)
#
# File ~/anaconda3/envs/asim/lib/python3.13/site-packages/viser/infra/_async_message_buffer.py:83, in AsyncMessageBuffer.push(self, message)
#      76 self.message_event.set()
#      77 if self.atomic_counter == 0:
#      78     # This call is necessary to make sure that awaiting tasks are
#      79     # triggered correctly.
#      80     #
#      81     # If we're in an atomic block, this will happen when
#      82     # atomic_end() is called.
# ---> 83     self.event_loop.call_soon_threadsafe(self.message_event.set)
#
# File ~/anaconda3/envs/asim/lib/python3.13/asyncio/base_events.py:878, in BaseEventLoop.call_soon_threadsafe(self, callback, context, *args)
#     876 if handle._source_traceback:
#     877     del handle._source_traceback[-1]
# --> 878 self._write_to_self()
#     879 return handle
#
# File ~/anaconda3/envs/asim/lib/python3.13/asyncio/selector_events.py:152, in BaseSelectorEventLoop._write_to_self(self)
#     149     return
#     151 try:
# --> 152     csock.send(b'\0')
#     153 except OSError:
#     154     if self._debug:
#
# KeyboardInterrupt:
