# %%
import matplotlib.pyplot as plt
from shapely.geometry import LineString, Polygon, Point
import numpy as np

from typing import List
import os
from pathlib import Path

from nuplan.database.nuplan_db_orm.nuplandb import LidarBox

import pyarrow as pa
import pyarrow.ipc as ipc

import numpy as np
from tqdm import tqdm

from asim.common.geometry.base import StateSE3
from asim.common.geometry.bounding_box.bounding_box import BoundingBoxSE3
from asim.common.geometry.constants import DEFAULT_ROLL, DEFAULT_PITCH

# %%
from asim.dataset.maps.abstract_map import MapSurfaceType

# %%
from nuplan.database.nuplan_db_orm.nuplandb import NuPlanDB

# %%
from asim.dataset.dataset_specific.nuplan.data_conversion import NuPlanDataset


NUPLAN_DATA_ROOT = Path(os.environ["NUPLAN_DATA_ROOT"])
SPLIT_PATH = NUPLAN_DATA_ROOT / "nuplan-v1.1" / "splits" / "mini"


db_files = list(SPLIT_PATH.iterdir())
# idx = 0
# for idx in range(len(db_files)):
idx = 12

log_db = NuPlanDB(NUPLAN_DATA_ROOT, str(db_files[idx]), None)
print(idx, log_db.log_name, log_db.log.map_version)
# Out:
# 12 2021.10.06.07.26.10_veh-52_00006_00398 sg-one-north

# %%
print(db_files[0].name[: -3])
# Out:
# 2021.06.07.12.54.00_veh-35_01843_02314

# %%
dataset = NuPlanDataset(Path("/home/daniel/asim_workspace/data"), "mini")


# dataset.convert(log_db.log_name)

# %%
for db_file in db_files:
    dataset = NuPlanDataset(Path("/home/daniel/asim_workspace/data"), "mini")
    print(db_file.name)
    dataset.convert(db_file.name[: -3])
    del dataset
# Out:
# 2021.06.07.12.54.00_veh-35_01843_02314.db
#  90%|████████▉ | 4235/4710 [00:21<00:02, 198.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 for db_file in db_files:
#       2     print(db_file.name)
# ----> 3     dataset.convert(db_file.name[: -3])
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/nuplan/data_conversion.py:77, in NuPlanDataset.convert(self, log_name)
#      74 tables: Dict[str, pa.Table] = {}
#      76 tables["metadata_table"] = self._get_metadata_table(log_db)
# ---> 77 tables["recording_table"] = self._get_recording_table(log_db)
#      79 # multi_table = ArrowMultiTableFile(self._output_path / self._split / f"{log_name}.arrow")
#      80 log_file_path = self._output_path / self._split / f"{log_name}.arrow"
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/nuplan/data_conversion.py:137, in NuPlanDataset._get_recording_table(self, log_db)
#     134 ego_states_log.append(_extract_ego_state(lidar_pc))
#     136 # 4. Traffic lights
# --> 137 traffic_light_ids, traffic_light_types = _extract_traffic_lights(log_db, lidar_pc_token)
#     138 traffic_light_ids_log.append(traffic_light_ids)
#     139 traffic_light_types_log.append(traffic_light_types)
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/nuplan/data_conversion.py:238, in _extract_traffic_lights(log_db, lidar_pc_token)
#     236 traffic_light_ids: List[int] = []
#     237 traffic_light_types: List[int] = []
# --> 238 traffic_lights = log_db.traffic_light_status.select_many(lidar_pc_token=lidar_pc_token)
#     239 for traffic_light in traffic_lights:
#     240     traffic_light_ids.append(int(traffic_light.lane_connector_id))
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/nuplan/database/common/db.py:224, in Table.select_many(self, **filters)
#     216 def select_many(self, **filters: Any) -> List[T]:
#     217     """
#     218     Query table using filters.
#     219         boston_logs = nuplandb.log.select_many(location='boston').
#    (...)
#     222     :return: A list of records mathing the given filters.
#     223     """
# --> 224     return self._session.query(self._table).filter_by(**filters).all()
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/query.py:1793, in Query.filter_by(self, **kwargs)
#    1785 if from_entity is None:
#    1786     raise sa_exc.InvalidRequestError(
#    1787         "Can't use filter_by when the first entity '%s' of a query "
#    1788         "is not a mapped class. Please use the filter method instead, "
#    1789         "or change the order of the entities in the query"
#    1790         % self._query_entity_zero()
#    1791     )
# -> 1793 clauses = [
#    1794     _entity_namespace_key(from_entity, key) == value
#    1795     for key, value in kwargs.items()
#    1796 ]
#    1797 return self.filter(*clauses)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/query.py:1794, in <listcomp>(.0)
#    1785 if from_entity is None:
#    1786     raise sa_exc.InvalidRequestError(
#    1787         "Can't use filter_by when the first entity '%s' of a query "
#    1788         "is not a mapped class. Please use the filter method instead, "
#    1789         "or change the order of the entities in the query"
#    1790         % self._query_entity_zero()
#    1791     )
#    1793 clauses = [
# -> 1794     _entity_namespace_key(from_entity, key) == value
#    1795     for key, value in kwargs.items()
#    1796 ]
#    1797 return self.filter(*clauses)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/operators.py:360, in ColumnOperators.__eq__(self, other)
#     353 def __eq__(self, other):
#     354     """Implement the ``==`` operator.
#     355
#     356     In a column context, produces the clause ``a = b``.
#     357     If the target is ``None``, produces ``a IS NULL``.
#     358
#     359     """
# --> 360     return self.operate(eq, other)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/attributes.py:317, in QueryableAttribute.operate(self, op, *other, **kwargs)
#     316 def operate(self, op, *other, **kwargs):
# --> 317     return op(self.comparator, *other, **kwargs)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/operators.py:360, in ColumnOperators.__eq__(self, other)
#     353 def __eq__(self, other):
#     354     """Implement the ``==`` operator.
#     355
#     356     In a column context, produces the clause ``a = b``.
#     357     If the target is ``None``, produces ``a IS NULL``.
#     358
#     359     """
# --> 360     return self.operate(eq, other)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/properties.py:431, in ColumnProperty.Comparator.operate(self, op, *other, **kwargs)
#     430 def operate(self, op, *other, **kwargs):
# --> 431     return op(self.__clause_element__(), *other, **kwargs)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/annotation.py:221, in Annotated.__eq__(self, other)
#     219 def __eq__(self, other):
#     220     if self._is_column_operators:
# --> 221         return self.__element.__class__.__eq__(self, other)
#     222     else:
#     223         return hash(other) == hash(self)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/operators.py:360, in ColumnOperators.__eq__(self, other)
#     353 def __eq__(self, other):
#     354     """Implement the ``==`` operator.
#     355
#     356     In a column context, produces the clause ``a = b``.
#     357     If the target is ``None``, produces ``a IS NULL``.
#     358
#     359     """
# --> 360     return self.operate(eq, other)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:858, in ColumnElement.operate(self, op, *other, **kwargs)
#     857 def operate(self, op, *other, **kwargs):
# --> 858     return op(self.comparator, *other, **kwargs)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/operators.py:360, in ColumnOperators.__eq__(self, other)
#     353 def __eq__(self, other):
#     354     """Implement the ``==`` operator.
#     355
#     356     In a column context, produces the clause ``a = b``.
#     357     If the target is ``None``, produces ``a IS NULL``.
#     358
#     359     """
# --> 360     return self.operate(eq, other)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/sql/type_api.py:1177, in TypeDecorator.Comparator.operate(self, op, *other, **kwargs)
#    1176 def operate(self, op, *other, **kwargs):
# -> 1177     kwargs["_python_is_types"] = self.expr.type.coerce_to_is_types
#    1178     return super(TypeDecorator.Comparator, self).operate(
#    1179         op, *other, **kwargs
#    1180     )
#
# KeyboardInterrupt:
