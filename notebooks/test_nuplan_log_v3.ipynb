# %%
import matplotlib.pyplot as plt
from shapely.geometry import LineString, Polygon, Point
import numpy as np

from typing import List
import os
from pathlib import Path

from nuplan.database.nuplan_db_orm.nuplandb import LidarBox

import pyarrow as pa
import pyarrow.ipc as ipc

import numpy as np
from tqdm import tqdm

from asim.common.geometry.base import StateSE3
from asim.common.geometry.bounding_box.bounding_box import BoundingBoxSE3
from asim.common.geometry.constants import DEFAULT_ROLL, DEFAULT_PITCH

# %%
from asim.dataset.maps.abstract_map import MapSurfaceType

# %%
from nuplan.database.nuplan_db_orm.nuplandb import NuPlanDB

# %%
from asim.dataset.dataset_specific.nuplan.data_conversion import NuPlanDataset


NUPLAN_DATA_ROOT = Path(os.environ["NUPLAN_DATA_ROOT"])
SPLIT_PATH = NUPLAN_DATA_ROOT / "nuplan-v1.1" / "splits" / "mini"


db_files = list(SPLIT_PATH.iterdir())
# idx = 0
# for idx in range(len(db_files)):
idx = 12

log_db = NuPlanDB(NUPLAN_DATA_ROOT, str(db_files[idx]), None)
print(idx, log_db.log_name, log_db.log.map_version)
# Out:
# 12 2021.10.06.07.26.10_veh-52_00006_00398 sg-one-north

# %%
print(db_files[0].name[: -3])
# Out:
# 2021.06.07.12.54.00_veh-35_01843_02314

# %%
dataset = NuPlanDataset(Path("/home/daniel/asim_workspace/data"), "mini")


# dataset.convert(log_db.log_name)

# %%
for db_file in db_files:
    print(db_file.name)
    dataset.convert(db_file.name[: -3])
# Out:
# 2021.06.07.12.54.00_veh-35_01843_02314.db
#   3%|▎         | 309/9420 [00:01<00:43, 207.71it/s]Error closing cursor
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py", line 1686, in _fetchall_impl
#     return list(self.iterator)
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/loading.py", line 147, in chunks
#     fetch = cursor._raw_all_rows()
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py", line 391, in _raw_all_rows
#     rows = self._fetchall_impl()
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py", line 1803, in _fetchall_impl
#     return self.cursor_strategy.fetchall(self, self.cursor)
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py", line 981, in fetchall
#     self.handle_exception(result, dbapi_cursor, e)
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py", line 941, in handle_exception
#     result.connection._handle_dbapi_exception(
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2030, in _handle_dbapi_exception
#     util.raise_(exc_info[1], with_traceback=exc_info[2])
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py", line 977, in fetchall
#     rows = dbapi_cursor.fetchall()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/daniel/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1897, in _safe_close_cursor
#     cursor.close()
# sqlite3.ProgrammingError: Cannot operate on a closed database.
#   3%|▎         | 323/9420 [00:01<00:47, 193.41it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 for db_file in db_files:
#       2     print(db_file.name)
# ----> 3     dataset.convert(db_file.name[: -3])
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/nuplan/data_conversion.py:77, in NuPlanDataset.convert(self, log_name)
#      74 tables: Dict[str, pa.Table] = {}
#      76 tables["metadata_table"] = self._get_metadata_table(log_db)
# ---> 77 tables["recording_table"] = self._get_recording_table(log_db)
#      79 # multi_table = ArrowMultiTableFile(self._output_path / self._split / f"{log_name}.arrow")
#      80 log_file_path = self._output_path / self._split / f"{log_name}.arrow"
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/nuplan/data_conversion.py:137, in NuPlanDataset._get_recording_table(self, log_db)
#     134 ego_states_log.append(_extract_ego_state(lidar_pc))
#     136 # 4. Traffic lights
# --> 137 traffic_light_ids, traffic_light_types = _extract_traffic_lights(log_db, lidar_pc_token)
#     138 traffic_light_ids_log.append(traffic_light_ids)
#     139 traffic_light_types_log.append(traffic_light_types)
#
# File ~/asim_workspace/asim/asim/dataset/dataset_specific/nuplan/data_conversion.py:238, in _extract_traffic_lights(log_db, lidar_pc_token)
#     236 traffic_light_ids: List[int] = []
#     237 traffic_light_types: List[int] = []
# --> 238 traffic_lights = log_db.traffic_light_status.select_many(lidar_pc_token=lidar_pc_token)
#     239 for traffic_light in traffic_lights:
#     240     traffic_light_ids.append(int(traffic_light.lane_connector_id))
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/nuplan/database/common/db.py:224, in Table.select_many(self, **filters)
#     216 def select_many(self, **filters: Any) -> List[T]:
#     217     """
#     218     Query table using filters.
#     219         boston_logs = nuplandb.log.select_many(location='boston').
#    (...)
#     222     :return: A list of records mathing the given filters.
#     223     """
# --> 224     return self._session.query(self._table).filter_by(**filters).all()
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/query.py:2759, in Query.all(self)
#    2743 def all(self):
#    2744     """Return the results represented by this :class:`_query.Query`
#    2745     as a list.
#    2746
#    (...)
#    2757             :ref:`faq_query_deduplicating`
#    2758     """
# -> 2759     return self._iter().all()
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py:1361, in ScalarResult.all(self)
#    1353 def all(self):
#    1354     """Return all scalar values in a list.
#    1355
#    1356     Equivalent to :meth:`_result.Result.all` except that
#    (...)
#    1359
#    1360     """
# -> 1361     return self._allrows()
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py:400, in ResultInternal._allrows(self)
#     396 post_creational_filter = self._post_creational_filter
#     398 make_row = self._row_getter
# --> 400 rows = self._fetchall_impl()
#     401 if make_row:
#     402     made_rows = [make_row(row) for row in rows]
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py:1274, in FilterResult._fetchall_impl(self)
#    1273 def _fetchall_impl(self):
# -> 1274     return self._real_result._fetchall_impl()
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py:1686, in IteratorResult._fetchall_impl(self)
#    1683     self._raise_hard_closed()
#    1685 try:
# -> 1686     return list(self.iterator)
#    1687 finally:
#    1688     self._soft_close()
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/orm/loading.py:147, in instances.<locals>.chunks(size)
#     145         break
#     146 else:
# --> 147     fetch = cursor._raw_all_rows()
#     149 if single_entity:
#     150     proc = process[0]
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/result.py:391, in ResultInternal._raw_all_rows(self)
#     389 def _raw_all_rows(self):
#     390     make_row = self._row_getter
# --> 391     rows = self._fetchall_impl()
#     392     return [make_row(row) for row in rows]
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py:1803, in CursorResult._fetchall_impl(self)
#    1802 def _fetchall_impl(self):
# -> 1803     return self.cursor_strategy.fetchall(self, self.cursor)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py:981, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#     979     return rows
#     980 except BaseException as e:
# --> 981     self.handle_exception(result, dbapi_cursor, e)
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py:941, in CursorFetchStrategy.handle_exception(self, result, dbapi_cursor, err)
#     940 def handle_exception(self, result, dbapi_cursor, err):
# --> 941     result.connection._handle_dbapi_exception(
#     942         err, None, None, dbapi_cursor, result.context
#     943     )
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2030, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2026         util.raise_(
#    2027             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028         )
#    2029     else:
# -> 2030         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2032 finally:
#    2033     del self._reentrant_error
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/envs/asim/lib/python3.9/site-packages/sqlalchemy/engine/cursor.py:977, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#     975 def fetchall(self, result, dbapi_cursor):
#     976     try:
# --> 977         rows = dbapi_cursor.fetchall()
#     978         result._soft_close()
#     979         return rows
#
# KeyboardInterrupt:
